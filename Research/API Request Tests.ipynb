# %%
api_key = "AIzaSyB8MdMCdvVq3fJFAwNf5q8FuMNbSpMGuj4"

# %%
from __future__ import division
from datetime import datetime 
import requests
from lxml import html, etree
import json

import pandas as pd

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

pd.options.display.max_columns = 100
pd.options.display.max_rows = 35
pd.options.display.width = 120

# %%
parameters = {"part": "snippet",
              "maxResults": 5,
              "order": "date",
              "pageToken": "",
              "publishedAfter": "2008-08-04T00:00:00Z",
              "publishedBefore": "2008-11-04T00:00:00Z",
              "q": "",
              "key": api_key,
              "type": "video",
              }
url = "https://www.googleapis.com/youtube/v3/search"

# %%
parameters["q"] = "Mark Udall"
page = requests.request(method="get", url=url, params=parameters)
j_results = json.loads(page.text)
print(page.text)
# Out:
# {
#  "kind": "youtube#searchListResponse",
#  "etag": "\"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/MXePCCM9J9v2Z5I-7AEWVe7xhM4\"",
#  "nextPageToken": "CAUQAA",
#  "regionCode": "US",
#  "pageInfo": {
#   "totalResults": 1614,
#   "resultsPerPage": 5
#  },
#  "items": [
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/RnA5w3j8ncSBgZgLRRV4kFBJIgE\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "hvsNXSUcQzw"
#    },
#    "snippet": {
#     "publishedAt": "2008-11-03T14:48:11.000Z",
#     "channelId": "UCaXsK6jf0AddIiYEjYmzVWw",
#     "title": "Udall - Schaffer Debate",
#     "description": "Watch excerpts from the debate, sponsored by the Denver Metro Chamber, that took place on October 7 at the Colorado Convention Center.",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/hvsNXSUcQzw/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/hvsNXSUcQzw/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/hvsNXSUcQzw/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "Rocky Mountain PBS",
#     "liveBroadcastContent": "none"
#    }
#   },
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/e9fIL2o6bt_KTg7cMGokuvrr5AU\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "nnghUTeSKW0"
#    },
#    "snippet": {
#     "publishedAt": "2008-11-03T00:06:40.000Z",
#     "channelId": "UC9ZGcEDoHfuY8lB5_SknuLA",
#     "title": "mark udall",
#     "description": "gov project.",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/nnghUTeSKW0/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/nnghUTeSKW0/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/nnghUTeSKW0/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "g072091",
#     "liveBroadcastContent": "none"
#    }
#   },
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/enNGKrT606vhyMvXDhjAIxhZ8mA\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "Pq-KnAMpDHs"
#    },
#    "snippet": {
#     "publishedAt": "2008-11-01T00:55:26.000Z",
#     "channelId": "UC5QhjJAjxtRvJ9ujFxNiJbA",
#     "title": "Eden Lane One on One with Congressman Mark Udall",
#     "description": "Senate candidate, Congressman Mark Udall spoke with me at a campaign event. Congressional candidate Jared Polis, and State Senate Candidate Joe ...",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/Pq-KnAMpDHs/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/Pq-KnAMpDHs/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/Pq-KnAMpDHs/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "Eden Lane",
#     "liveBroadcastContent": "none"
#    }
#   },
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/EKTxtPtlBD_4UsrMHAquJq9els0\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "aITDlrkKOoY"
#    },
#    "snippet": {
#     "publishedAt": "2008-11-01T00:42:17.000Z",
#     "channelId": "UCT3P1V7_N5HzV1vEZUSdNNQ",
#     "title": "CO: AFGE, APWU, NALC, and NPMHU leaflet with Mark Udall",
#     "description": "APWU, NALC, and NPMHU are out at the worksite when it matters most!",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/aITDlrkKOoY/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/aITDlrkKOoY/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/aITDlrkKOoY/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "Bernard Pollack",
#     "liveBroadcastContent": "none"
#    }
#   },
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/iHopyRaJWiRBcJMzsqyqgWmp4_A\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "FvfF_6l9IoQ"
#    },
#    "snippet": {
#     "publishedAt": "2008-10-30T11:28:08.000Z",
#     "channelId": "UCBq-CNF9ltJMirhCoDlxLkA",
#     "title": "Udall IE   \"Playing Politics\" - Visual Radio Message",
#     "description": "http://www.aao.org/ Udall for Senate 2008 Visual Radio Message, American Academy of Ophthalmologists PAC.",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/FvfF_6l9IoQ/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/FvfF_6l9IoQ/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/FvfF_6l9IoQ/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "ophthpac4udall",
#     "liveBroadcastContent": "none"
#    }
#   }
#  ]
# }

# %%
parameters = {"part": "statistics",
              "id": "5Q98TvXjIZg",
              "key": api_key,
              }
url = "https://www.googleapis.com/youtube/v3/videos"

# %%
page = requests.request(method="get", url=url, params=parameters)
j_results = json.loads(page.text)
print(page.text)
# Out:
# {
#  "kind": "youtube#videoListResponse",
#  "etag": "\"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/2T5pHpo3vhwE1waFZ1vz3M3s5DE\"",
#  "pageInfo": {
#   "totalResults": 1,
#   "resultsPerPage": 1
#  },
#  "items": [
#   {
#    "kind": "youtube#video",
#    "etag": "\"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/fPf65uXkTCIvwIEsMEYIwOazPZA\"",
#    "id": "5Q98TvXjIZg",
#    "statistics": {
#     "viewCount": "80",
#     "likeCount": "0",
#     "dislikeCount": "0",
#     "favoriteCount": "0"
#    }
#   }
#  ]
# }
